# %% [markdown]
# ## Mount the following data lake storage gen2 containers
# 1. raw
# 2. processed
# 3. lookup

# %% [markdown]
# ### Set-up the configs
# #### Please update the following
# - application-id
# - service-credential
# - directory-id

# %%
configs = {"fs.azure.account.auth.type": "OAuth",
           "fs.azure.account.oauth.provider.type": "org.apache.hadoop.fs.azurebfs.oauth2.ClientCredsTokenProvider",
           "fs.azure.account.oauth2.client.id": "e93c84eb-e25e-457e-8c4d-845573d4b335",
           "fs.azure.account.oauth2.client.secret": "Owp7Q~QQGTc9OwxSFWh3rVza2Lb31Lpp-1djk",
           "fs.azure.account.oauth2.client.endpoint": "https://login.microsoftonline.com/6c51c659-9d52-41af-81f7-dde16380e813/oauth2/token"}
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### Mount the raw container
# #### Update the storage account name before executing

# %%
dbutils.fs.mount(
  source = "abfss://raw@mdcovidreportdl.dfs.core.windows.net/",
  mount_point = "/mnt/mdcovidreportdl/raw",
  extra_configs = configs)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[2]: True</div>

# %% [markdown]
# ### Mount the processed container
# #### Update the storage account name before executing

# %%
dbutils.fs.mount(
  source = "abfss://processed@mdcovidreportdl.dfs.core.windows.net/",
  mount_point = "/mnt/mdcovidreportdl/processed",
  extra_configs = configs)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[3]: True</div>

# %% [markdown]
# ### Mount the lookup container
# #### Update the storage account name before executing

# %%
dbutils.fs.mount(
  source = "abfss://lookup@mdcovidreportdl.dfs.core.windows.net/",
  mount_point = "/mnt/mdcovidreportdl/lookup",
  extra_configs = configs)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[4]: True</div>

# %%
dbutils.fs.ls("/mnt/mdcovidreportdl/lookup")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[5]: [FileInfo(path=&#39;dbfs:/mnt/mdcovidreportdl/lookup/dim_country/&#39;, name=&#39;dim_country/&#39;, size=0),
#  FileInfo(path=&#39;dbfs:/mnt/mdcovidreportdl/lookup/dim_date/&#39;, name=&#39;dim_date/&#39;, size=0)]</div>

# %%
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
